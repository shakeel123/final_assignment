# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Shakeel Ahmed**

# %% [markdown]
# Data Scientist

# %% [markdown]
# _I am interested in data science because I enjoyed dig up the data and information specially from healthcare data sec I enjoyed the clinical research work from the healthcare sector looking forward to do some projects in this department_

# %% [markdown]
# ***My code in next cell will import and print the python library called Pandas***

# %%
import pandas as pd

# %% [markdown]
# I am new to python language
# ***
# I want to learn data science with python

# %% [markdown]
# ![SNOWFALL](snowfall4.jpeg)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('uns8vUQNxpc', width = 800, height = 500)

# %% [markdown]
# <font color=pink>The above video shows python </font> <br>
# <font color=green>The above video shows python </font> <br>
# <font color=yellow>The above video shows python </font> <br>
# <font color=red>The above video shows python </font>

# %% [markdown]
#  - this <br>
#  - is <br>
#  - awsome<br>
#  - course

# %% [markdown]
# <ol>
# <li>Python</li>
# <li>SQL</li>
# <li>R</li>
# </ol>
