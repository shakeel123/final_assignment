# %% [markdown]
# ## A Complete EDA Analysis on Athletes of Denmark
# This report created by Shakeel Ahmed

# %% [markdown]
# This Project exploratory data analysis on athletes of Denmark who Participated in World Olympics Games. This is  by done with the help of Dataset athlete.csv, getting it from kaggle.
# please feel free to provide your valuable feedback
#
# I pulled athletes data for th from Kaggle and analyzed the data for Mostly Gold Medalist. The column fields are pretty self explainatory

# %% [markdown]
# Let’s Start with importing the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import datetime
# %matplotlib inline

# %% [markdown]
# Collecting information about both the data sets
# We are going to:
# 1 Review the first lines of the data
# 2 Use the describe and info functions to collect statistical information, datatypes, column names and other information.

# %%
#Collecting information ,Reading Data
df1 = pd.read_csv('/Users/shakeelsunny/Dropbox/project Python/sio209/data/athlete_events.csv'
                )
df1.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df1.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
#Collection information for region based , Reading Data
df2 = pd.read_csv('/Users/shakeelsunny/Dropbox/project Python/sio209/data/noc_regions.csv'
                )
df2.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
merged = pd.merge(df1, df2, on='NOC', how='left')
merged.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# ...

# %%
Gold = merged[(merged.Medal == 'Gold')]
Gold.head()
# Out:
#     ID                     Name Sex   Age  Height  Weight            Team  \
# 3    4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0          Norway
#
#     NOC        Games  Year  Season         City          Sport  \
# 3   DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 42  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 44  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 48  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 60  NOR  1992 Winter  1992  Winter  Albertville  Alpine Skiing
#
#                                Event Medal   region notes
# 3        Tug-Of-War Men's Tug-Of-War  Gold  Denmark   NaN
# ...

# %%
Gold.isnull().any()
# Out:
# ID        False
# Name      False
# Sex       False
# Age        True
# Height     True
# Weight     True
# Team      False
# NOC       False
# Games     False
# Year      False
# Season    False
# City      False
# Sport     False
# Event     False
# Medal     False
# region     True
# notes      True
# dtype: bool

# %%
Gold = merged[(merged.Medal == 'Gold') & (merged.region == 'Denmark')]
Gold
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4073      2347    Georg Albert Christian Albertsen   M  30.0     NaN     NaN
# 5061      2882             Ejler Arild Emil Allert   M  30.0     NaN     NaN
# 6587      3684       Aage Jrgen Christian Andersen   M  22.0     NaN     NaN
# 6597      3690                   Anja Jul Andersen   F  27.0   178.0     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 252032  126212  Mette Vestergaard Larsen (-Brandt)   F  24.0   172.0    64.0
# 252033  126212  Mette Vestergaard Larsen (-Brandt)   F  28.0   172.0    64.0
# 254232  127294  Christian Robert von Blow af Radum   M  46.0   173.0    73.0
# 257220  128801                        Jonas Warrer   M  29.0   181.0    77.0
# 261705  130945     Charles Gustav Wilhelm Winckler   M  33.0     NaN     NaN
#
# ...

# %%
Gold[Gold.Age == Gold.Age.max()]
# Out:
#            ID                  Name Sex   Age  Height  Weight     Team  NOC  \
# 171029  85949  Anders Peter Nielsen   M  52.0     NaN     NaN  Denmark  DEN
#
#               Games  Year  Season       City     Sport  \
# 171029  1920 Summer  1920  Summer  Antwerpen  Shooting
#
#                                                     Event Medal   region notes
# 171029  Shooting Men's Military Rifle, Standing, 300 m...  Gold  Denmark   NaN

# %% [markdown]
# ### Anders Peter Nielsen
# So we got Anders Peter Nielsen is the eldest among the Males who won Gold Medal in Shooting.

# %%
Gold[Gold.Age == Gold.Age.min()]
# Out:
#           ID        Name Sex   Age  Height  Weight     Team  NOC        Games  \
# 97669  49435  Harry Holm   M  17.0     NaN     NaN  Denmark  DEN  1920 Summer
#
#        Year  Season       City       Sport  \
# 97669  1920  Summer  Antwerpen  Gymnastics
#
#                                                Event Medal   region notes
# 97669  Gymnastics Men's Team All-Around, Free System  Gold  Denmark   NaN

# %% [markdown]
# ### Harry Holm
# So we got Harry Holm is the Youngest among the Males who won Gold Medal in Gymnastics.

# %%
Gold['Sex'].max()
# Out:
# 'M'

# %%
plt.figure(figsize=(15, 5))
plt.tight_layout()
sns.countplot(Gold['Age'])
plt.title('Distribution of Gold Medals with age')
# Out:
# /Users/shakeelsunny/miniconda3/envs/python3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Distribution of Gold Medals with age')

# %%
Gold['ID'][Gold['Age'] > 35].count()
# Out:
# 9

# %% [markdown]
# ## 9 people: Great!
# But which disciplines allows you to land a gold medal after your fifties?
# We will now create a new dataframe called masterDisciplines in which we will insert this new set of people and then create a visualization with it.

# %% [markdown]
# It seems that we have people with Age less that 14 with a gold medal: Let’s know more about those people!

# %%
Gold['ID'][Gold['Age'] < 20].count()
# Out:
# 5

# %% [markdown]
# ## 5 Teenagers: Great!

# %%
Disciplines = Gold['Sport'][Gold['Age'] < 55]
plt.figure(figsize=(20, 5))
plt.tight_layout()
sns.countplot(Disciplines)
plt.title('Gold Medals for Athletes')
# Out:
# /Users/shakeelsunny/miniconda3/envs/python3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gold Medals for Athletes')

# %% [markdown]
# # Women in Athletics
#
# Studying the data we can try to understan how much medals we have only for women in the recent history of the Summer Games. Let’s create a filtered dataset :

# %%
women = merged[(merged.Sex == 'F') & (merged.region == 'Denmark') & (merged.Medal == 'Gold')]
women.head()
# Out:
#         ID                                         Name Sex   Age  Height  \
# 6597  3690                            Anja Jul Andersen   F  27.0   178.0
# 6612  3701                      Camilla Rseler Andersen   F  23.0   169.0
# 6613  3701                      Camilla Rseler Andersen   F  27.0   169.0
# 6652  3725  Greta Marie Andersen (-Sonnichsen, -Veress)   F  21.0     NaN
# 6706  3756                            Kristine Andersen   F  28.0   172.0
#
#       Weight     Team  NOC        Games  Year  Season     City     Sport  \
# 6597     NaN  Denmark  DEN  1996 Summer  1996  Summer  Atlanta  Handball
# 6612    65.0  Denmark  DEN  1996 Summer  1996  Summer  Atlanta  Handball
# 6613    65.0  Denmark  DEN  2000 Summer  2000  Summer   Sydney  Handball
# 6652     NaN  Denmark  DEN  1948 Summer  1948  Summer   London  Swimming
# 6706    72.0  Denmark  DEN  2004 Summer  2004  Summer   Athina  Handball
#
#                                       Event Medal   region notes
# ...

# %%
women['Age'].max()
# Out:
# 33.0

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(15, 5))
sns.countplot(x='Year', data=women)
plt.title('Women Goldmedalist per edition of the Games')
# Out:
# Text(0.5, 1.0, 'Women Goldmedalist per edition of the Games')

# %%
women[women.Age == women.Age.max()]
# Out:
#            ID                             Name Sex   Age  Height  Weight  \
# 178558  89754  Ellen Ottilia Osiier (Thomsen-)   F  33.0   168.0     NaN
#
#            Team  NOC        Games  Year  Season   City    Sport  \
# 178558  Denmark  DEN  1924 Summer  1924  Summer  Paris  Fencing
#
#                                    Event Medal   region notes
# 178558  Fencing Women's Foil, Individual  Gold  Denmark   NaN

# %% [markdown]
# ### Ellen Ottilia Osiier (Thomsen)
# So we got Ellen Ottilia Osiier (Thomsen) is the eldest among females who won Gold Medal in Fencing.

# %%
women[women.Age == women.Age.min()]
# Out:
#           ID                                            Name Sex   Age  \
# 42511  21927  Anna Stefanie Nanny Fryland Clausen (-Fryland)   F  20.0
#
#        Height  Weight     Team  NOC        Games  Year  Season       City  \
# 42511     NaN     NaN  Denmark  DEN  1920 Summer  1920  Summer  Antwerpen
#
#         Sport                      Event Medal   region notes
# 42511  Diving  Diving Women's Plain High  Gold  Denmark   NaN

# %% [markdown]
# ### Anna Stefanie Nanny
# So we got Anna Stefanie Nanny  is the eldest among females who won Gold Medal in Diving.
# ![me.jpeg](attachment:me.jpeg)

# %% [markdown]
# # Women Gold Medalist Vs Men Gold Medalist
# Let’s now review the  gender ratio gold medalist of Denmark:

# %%
# plot a pie and bar plot using subplots(1,2,figsize=(8,5))
fig,axes = plt.subplots(1,2,figsize=(15,5))
Gold["Sex"].value_counts().plot(kind="bar", ax=axes[0],color =['DarkRed','indianred','darksalmon'])
Gold["Sex"].value_counts().plot(kind="pie",ax=axes[1],autopct='%0.2f', colormap="Spectral")
plt.show()

# %%
Gold.Sex.value_counts().reset_index(name='Medal').head()
# Out:
#   index  Medal
# 0     M    127
# 1     F     52

# %% [markdown]
# ### Male Gold Medalist  = 127,
#                            70.95%
# ### Femela Gold Medalist = 52,
#                            29.05%

# %% [markdown]
# # What is the median height/weight of an Olympic medalist?

# %% [markdown]
# Let’s try to plot a scatterplot of height vs weight to see the distribution of values (without grouping by discipline).

# %% [markdown]
# First of all, we have to take again the goldMedals dataframe

# %%
Gold.head()
# Out:
#         ID                              Name Sex   Age  Height  Weight  \
# 3        4              Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4073  2347  Georg Albert Christian Albertsen   M  30.0     NaN     NaN
# 5061  2882           Ejler Arild Emil Allert   M  30.0     NaN     NaN
# 6587  3684     Aage Jrgen Christian Andersen   M  22.0     NaN     NaN
# 6597  3690                 Anja Jul Andersen   F  27.0   178.0     NaN
#
#                        Team  NOC        Games  Year  Season       City  \
# 3            Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris
# 4073                Denmark  DEN  1920 Summer  1920  Summer  Antwerpen
# 5061  Nykjbings paa Falster  DEN  1912 Summer  1912  Summer  Stockholm
# 6587                Denmark  DEN  1906 Summer  1906  Summer     Athina
# 6597                Denmark  DEN  1996 Summer  1996  Summer    Atlanta
#
#            Sport                                          Event Medal  \
# ...

# %% [markdown]
# We can see that we have NaN values both in height and weight columns.

# %% [markdown]
# At this point, we can act as follows:
#
# 1. Using only the rows that has a value in the Height and Weight columns
#
# 2. Replace the value with the mean of the column.

# %% [markdown]
# Let’s go with solution 1.

# %% [markdown]
# The first thing to do is to collect general information about the dataframe that we have to use: goldMedals.

# %%
Gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179 entries, 3 to 261705
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      179 non-null    int64
#  1   Name    179 non-null    object
#  2   Sex     179 non-null    object
#  3   Age     179 non-null    float64
#  4   Height  106 non-null    float64
#  5   Weight  101 non-null    float64
#  6   Team    179 non-null    object
#  7   NOC     179 non-null    object
#  8   Games   179 non-null    object
#  9   Year    179 non-null    int64
#  10  Season  179 non-null    object
#  11  City    179 non-null    object
#  12  Sport   179 non-null    object
#  13  Event   179 non-null    object
#  14  Medal   179 non-null    object
#  15  region  179 non-null    object
#  16  notes   0 non-null      object
# dtypes: float64(3), int64(2), object(12)
# memory usage: 29.2+ KB

# %% [markdown]
# Okay, we have 179 records.

# %% [markdown]
# We will now create a dataframe filtering only the rows that has the column Height and Weight populated.

# %%
notNullMedals = Gold[(Gold['Height'].notnull()) & (Gold['Weight'].notnull())]

# %%
plt.figure(figsize=(10, 5))
ax = sns.scatterplot(x="Height", y="Weight", data=notNullMedals)
plt.title('Height vs Weight of Olympic Medalists')
# Out:
# Text(0.5, 1.0, 'Height vs Weight of Olympic Medalists')

# %% [markdown]
# The vast majority of the samples show a linear relation between height and weight (the more the weight, the more the height).

# %% [markdown]
# We have exceptions and I am willing to know more!

# %% [markdown]
# For example, let’s see which is the athlete that weighs more than 160 kilograms.

# %%
notNullMedals.loc[notNullMedals['Weight'] > 100]
# Out:
#            ID                    Name Sex   Age  Height  Weight     Team  NOC  \
# 90256   45732      Henrik Toft Hansen   M  29.0   200.0   105.0  Denmark  DEN
# 90361   45793         Ren Toft Hansen   M  31.0   200.0   105.0  Denmark  DEN
# 107590  54379  Henrik Mllgaard Jensen   M  31.0   197.0   102.0  Denmark  DEN
# 131775  66315  Niklas Landin Jacobsen   M  27.0   201.0   102.0  Denmark  DEN
# 132743  66820      Mads Mensah Larsen   M  24.0   188.0   106.0  Denmark  DEN
#
#               Games  Year  Season            City     Sport  \
# 90256   2016 Summer  2016  Summer  Rio de Janeiro  Handball
# 90361   2016 Summer  2016  Summer  Rio de Janeiro  Handball
# 107590  2016 Summer  2016  Summer  Rio de Janeiro  Handball
# 131775  2016 Summer  2016  Summer  Rio de Janeiro  Handball
# 132743  2016 Summer  2016  Summer  Rio de Janeiro  Handball
#
#                           Event Medal   region notes
# 90256   Handball Men's Handball  Gold  Denmark   NaN
# ...

# %% [markdown]
# # Variation of male/female athletes over time

# %% [markdown]
# We will now create two dataframes dividing the population of our dataset using Sex. we would like to review all season

# %%
MenOverTime = merged[(merged.Sex == 'M') & (merged.region=='Denmark')]
WomenOverTime = merged[(merged.Sex == 'F') & (merged.region =='Denmark')]

# %%
MenOverTime.head()
# Out:
#        ID                  Name Sex   Age  Height  Weight            Team  \
# 2       3   Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3       4  Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 1303  734    Otto Mnsted Acthon   M  30.0     NaN     NaN         Denmark
# 1304  734    Otto Mnsted Acthon   M  30.0     NaN     NaN         Denmark
# 1305  734    Otto Mnsted Acthon   M  34.0     NaN     NaN         Denmark
#
#       NOC        Games  Year  Season       City          Sport  \
# 2     DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3     DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 1303  DEN  1948 Summer  1948  Summer     London  Equestrianism
# 1304  DEN  1948 Summer  1948  Summer     London  Equestrianism
# 1305  DEN  1952 Summer  1952  Summer   Helsinki  Equestrianism
#
#                                                 Event Medal   region notes
# ...

# %%
part = MenOverTime.groupby('Year')['Sex'].value_counts()
plt.figure(figsize=(15, 5))
part.loc[:,'M'].plot()
plt.title('Variation of Male Athletes over time')
# Out:
# Text(0.5, 1.0, 'Variation of Male Athletes over time')

# %%
plt.figure(figsize=(15, 5))
sns.pointplot('Year', 'Height', data=MenOverTime, palette='Set2')
plt.title('Variation of Height for Male Athletes over time')
# Out:
# /Users/shakeelsunny/miniconda3/envs/python3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Variation of Height for Male Athletes over time')

# %%
part = WomenOverTime.groupby('Year')['Sex'].value_counts()
plt.figure(figsize=(15, 5))
part.loc[:,'F'].plot()
plt.title('Variation of Female Athletes over time')
# Out:
# Text(0.5, 1.0, 'Variation of Female Athletes over time')

# %%
plt.figure(figsize=(15, 5))
sns.pointplot('Year', 'Height', data=WomenOverTime, palette='Set2')
plt.title('Variation of Height for Female Athletes over time')
# Out:
# /Users/shakeelsunny/miniconda3/envs/python3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Variation of Height for Female Athletes over time')

# %%
plt.figure(figsize=(20, 10))
sns.boxplot('Year', 'Age', data=MenOverTime)
plt.title('Variation of Age for Male Athletes over time')
# Out:
# /Users/shakeelsunny/miniconda3/envs/python3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Variation of Age for Male Athletes over time')

# %%
MenOverTime.loc[MenOverTime['Age'] > 30].head(10)
# Out:
#         ID                             Name Sex   Age  Height  Weight  \
# 3        4             Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 1305   734               Otto Mnsted Acthon   M  34.0     NaN     NaN
# 1306   734               Otto Mnsted Acthon   M  34.0     NaN     NaN
# 4075  2348                 Johnny Albertsen   M  32.0   170.0    75.0
# 4076  2348                 Johnny Albertsen   M  32.0   170.0    75.0
# 6194  3479  Karl Vilhelm Nordstrm Ammitzbll   M  40.0     NaN     NaN
# 6195  3479  Karl Vilhelm Nordstrm Ammitzbll   M  40.0     NaN     NaN
# 6600  3693          Anton Kristian Andersen   M  39.0     NaN     NaN
# 6601  3693          Anton Kristian Andersen   M  39.0     NaN     NaN
# 6602  3693          Anton Kristian Andersen   M  39.0     NaN     NaN
#
#                 Team  NOC        Games  Year  Season       City  \
# 3     Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris
# 1305         Denmark  DEN  1952 Summer  1952  Summer   Helsinki
# ...

# %%
plt.figure(figsize=(20, 10))
sns.boxplot('Year', 'Age', data=WomenOverTime)
plt.title('Variation of Age for Female Athletes over time')
# Out:
# /Users/shakeelsunny/miniconda3/envs/python3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Variation of Age for Female Athletes over time')

# %%
MenOverTime.head()
# Out:
#        ID                  Name Sex   Age  Height  Weight            Team  \
# 2       3   Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3       4  Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 1303  734    Otto Mnsted Acthon   M  30.0     NaN     NaN         Denmark
# 1304  734    Otto Mnsted Acthon   M  30.0     NaN     NaN         Denmark
# 1305  734    Otto Mnsted Acthon   M  34.0     NaN     NaN         Denmark
#
#       NOC        Games  Year  Season       City          Sport  \
# 2     DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3     DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 1303  DEN  1948 Summer  1948  Summer     London  Equestrianism
# 1304  DEN  1948 Summer  1948  Summer     London  Equestrianism
# 1305  DEN  1952 Summer  1952  Summer   Helsinki  Equestrianism
#
#                                                 Event Medal   region notes
# ...

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(15, 5))
sns.countplot(x='Year', data=MenOverTime, palette='Set2')
plt.title('Variation of Age for Denmark Male Athletes over time')
# Out:
# Text(0.5, 1.0, 'Variation of Age for Denmark Male Athletes over time')

# %%
WomenOverTime = WomenOverTime.loc[WomenOverTime['region'] == 'Denmark']
sns.set(style="darkgrid")
plt.figure(figsize=(15, 5))
sns.countplot(x='Year', data=WomenOverTime, palette='Set2')
plt.title('Variation of Age for Denmark Female Athletes over time')
# Out:
# Text(0.5, 1.0, 'Variation of Age for Denmark Female Athletes over time')

# %% [markdown]
# ### This Note book is created by : Shakeel Ahmed.

# %% [markdown]
# Linkedin: https://www.linkedin.com/in/shakeel-ahmed956/
